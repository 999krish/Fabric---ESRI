# %% [markdown]
# # 🚀 **MSLA Ecuador Fire Project - Microsoft Fabric Notebook**
# ## **🌎 Understanding Ecuador & the 2024 Ecuador Fires**
# Ecuador, a **biodiverse country in South America**, is home to the **Amazon rainforest, Andean mountains, and Pacific coastline**.
# However, due to **climate change, deforestation, and human expansion**, Ecuador has become increasingly vulnerable to **wildfires**.
#
# ### **🔥 The 2024 Ecuador Fires: A National Crisis**
# - In early **2024, wildfires consumed over 76,000 hectares** of forests, farmland, and critical ecosystems.
# - **Deforestation, prolonged droughts, and El Niño conditions** exacerbated the spread and intensity of these fires.
# - The fires **devastated indigenous lands, destroyed agricultural fields, and displaced rural communities**.
# - **Smoke pollution** impacted major cities like **Quito, Guayaquil, and Cuenca**, causing public health concerns.
# - Ecuador’s government and emergency responders **lacked AI-driven fire risk assessment tools** to predict, prevent, and mitigate damages.
#
# ### **📸 Visualizing the Fire Crisis**
# ![Wildfire Impact in Ecuador](abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/31758563907_9d16e7bb84_k%20(1).jpg)
#
# ---
#
# ## **🛰️ The Role of Geospatial Intelligence (GEOINT)**
# **Geospatial Intelligence (GEOINT)** combines **satellite imagery, remote sensing, and AI-powered analytics** to provide actionable insights into **wildfire risk and disaster management**.
#
# ### **📌 How AI + GEOINT Helps Ecuador**
# - **Before Wildfires**: AI models predict **fire-prone zones** based on climate data, land use patterns, and historical fire occurrences.
# - **During Wildfires**: **Satellite-based heat anomaly detection** helps monitor active fires and guide emergency responses.
# - **After Wildfires**: Remote sensing evaluates **burn severity, soil erosion risks, and post-fire ecological recovery**.
#
# ![Satellite View of Wildfire Regions](abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/32284026688_3ce17103cc_k%20(1).jpg)
#
# ---
#
# ## **📂 Loading Data into Microsoft Fabric**
# ### **Building a Scalable AI-Powered Fire Analysis Pipeline**
# To analyze the **2024 Ecuador fires**, we integrated **multi-source geospatial datasets** into **Microsoft Fabric**, enabling **AI-driven analysis and visualization**.
#
# ### **📥 Datasets Integrated**
# ✅ **Landsat 8 & 9 + Sentinel-2 Satellite Imagery** – For **before-and-after fire impact analysis**.
# ✅ **ArcGIS Pro Raster & Vector Data** – To assess **fire spread, burn severity, and land-use change**.
# ✅ **Tabular Climate & Historical Fire Data** – Incorporating **temperature trends, vegetation indexes (NDVI/NBR), and historical fire locations**.
#
# ### **🔗 Microsoft Fabric for AI-Powered Processing**
# Once acquired, datasets were loaded into **Microsoft Fabric’s Data Engineering environment**, where they were:
# - **Preprocessed & Cleaned** – Removing cloud cover, normalizing spectral indices, and structuring tabular data.
# - **Indexed & Organized in OneLake** – A **centralized storage layer** for querying and retrieval.
# - **Analyzed using AI Models** – Applying **machine learning & geospatial algorithms** to detect patterns in fire risk and recovery.
#
# ### **📊 Visualizing Fire Risk & Recovery Trends**
# Fabric’s **AI and Power BI integrations** enabled:
# - **Burn Severity Classification** – Using **NBR & NDVI time-series** to track vegetation loss and regrowth.
# - **Predictive Fire Risk Mapping** – Generating **fire-prone zones** based on land cover, drought severity, and historical fire behavior.
# - **Near Real-Time Monitoring Dashboards** – Allowing stakeholders to interact with **fire data through ArcGIS Pro & Power BI**.
#
# ---
#
# ### **📸 Data-Driven Insights: Fire Spread & Recovery**
# ![Ecuador Fire Analysis Visualization](abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/52843874080_fac154dcb7_k%20(1).jpg)
#
# ---
#
# ## **1️⃣ Data Acquisition: Landsat and Fire Data**
# To analyze wildfire activity across Ecuador from **2020 to 2024**, we retrieved **Landsat imagery** using:
# - **Bulk Download Tool** – Enabled efficient retrieval of large Landsat datasets.
# - **ESPA (Earth Science Processing Architecture)** – Used for preprocessing and downloading spectral indices.
#
# ### **Key Indices Used**
# ✅ **Normalized Burn Ratio (NBR)** – Highlights burned areas using near-infrared (NIR) and shortwave infrared (SWIR) reflectance differences.
# ✅ **Normalized Difference Vegetation Index (NDVI)** – Measures vegetation health, useful for pre- and post-fire comparisons.
# ✅ **QA Pixel Data** – Identifies cloud cover, shadows, and sensor anomalies in Landsat images to improve data quality.
#
# ---
#
# ## **2️⃣ Spectral Band Analysis for Fire Detection**
# To further enhance our fire analysis, we examined **Landsat Bands 5, 6, and 7**, which are particularly effective for detecting burned areas and vegetation stress.
#
# | **Band**  | **Name**                        | **Wavelength (µm)**  | **Use in Fire Analysis** |
# |-----------|--------------------------------|----------------------|--------------------------|
# | **Band 5** | Near-Infrared (NIR)            | 0.85 – 0.88 µm       | Differentiates healthy vegetation from burned areas. |
# | **Band 6** | Shortwave Infrared (SWIR 1)    | 1.57 – 1.65 µm       | Detects vegetation moisture loss and highlights burned areas. |
# | **Band 7** | Shortwave Infrared (SWIR 2)    | 2.11 – 2.29 µm       | Identifies fire scars, heat signatures, and post-fire soil reflectance. |
#
# ---
#
# ## **3️⃣ GIS Analysis in Esri ArcGIS Pro**
# After preprocessing, we imported the cleaned raster data into **ArcGIS Pro** for geospatial analysis:
# - **Before-and-After Fire Impact:** Used NBR and NDVI to track vegetation loss and fire scars.
# - **Fire Severity Mapping:** Applied Band 7 to highlight high-burn areas.
# - **Regional Insights:** Integrated Ecuador-specific datasets to study:
#   - 🔹 **Population & urban expansion** near fire-prone zones.
#   - 🔹 **Protected areas & biodiversity loss** due to wildfires.
#   - 🔹 **Climate & land-use change trends** over time.
#
# ---
#
# ## **📌 Key Takeaways & Next Steps**
# ✅ **Early fire detection** and risk assessment using AI-driven geospatial analysis.
# ✅ **Data-driven insights** to inform disaster resilience strategies.
# ✅ **Microsoft Fabric + ArcGIS Pro** as a scalable **AI-GIS integration model**.

# %% [markdown]
# ### Ecuador Population 2021

# %%
import matplotlib.pyplot as plt
import PIL.Image
import fsspec
from io import BytesIO

# Define the full ABFS file path
image_path = "abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/Screenshot 2025-02-26 200626.png"

# Open image file using fsspec
with fsspec.open(image_path, mode="rb") as f:
    img_bytes = BytesIO(f.read())  # Read into memory
    img = PIL.Image.open(img_bytes)  # Open image from buffer

# Display the image
plt.figure(figsize=(10, 6))
plt.imshow(img)
plt.axis("off")  # Hide axes
plt.show()
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 49, Finished, Available, Finished)

# %% [markdown]
# ### Easy Drag and Drop CSV to Chart for Agricultural Land KM Over Time in Ecuador

# %%
df = spark.read.format("csv").option("header","true").load("Files/climate-change_ecu (1).csv")
# df now is a Spark DataFrame containing CSV data from "Files/climate-change_ecu (1).csv".
display(df)
# Out:
# StatementMeta(, d6b17465-3baf-4b08-9760-e2aef1cc3c7c, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 4394c256-c494-4850-9ede-22e3d679b9f1)

# %% [markdown]
# Data from World Bank Data: https://data.worldbank.org/indicator/SP.POP.TOTL?end=2023&locations=EC&start=2023&view=map

# %% [markdown]
# ### Ecuador Population Density (2021) Made in ArcGIS Pro

# %%
import matplotlib.pyplot as plt
import PIL.Image
import fsspec
from io import BytesIO

# Define the ABFS path
image_path = "abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/Population.png"

# Open the image directly from OneLake
with fsspec.open(image_path, mode="rb") as f:
    img_bytes = BytesIO(f.read())  # Read file into memory buffer
    img = PIL.Image.open(img_bytes)  # Open image from buffer

# Display the image
plt.figure(figsize=(10, 6))
plt.imshow(img)
plt.axis("off")  # Hide axes
plt.show()
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 45, Finished, Available, Finished)

# %% [markdown]
# # **🛰 MSLA Ecuador Fire Project: AI-Driven Fire Risk Analysis**
# ## **Leveraging Microsoft Fabric + Esri ArcGIS Pro for Wildfire Intelligence**
#
# ---
#
# ## **🔥 1. The Problem: Wildfires in Ecuador**
# Ecuador is home to **diverse ecosystems**, including **Amazon rainforests, Andean highlands, and coastal dry forests**.
# However, **wildfires have increased**, driven by:
# - **Climate change** (higher temperatures, drier conditions).
# - **Human activities** (deforestation, urban expansion, agricultural burns).
# - **Limited fire prediction & monitoring** capabilities.
#
# #### **📊 Why Fire Intelligence Matters**
# ✅ **Protecting biodiversity** – Ecuador hosts some of the world's most endangered species.
# ✅ **Safeguarding communities** – Wildfires threaten homes, infrastructure, and indigenous lands.
# ✅ **Supporting disaster response** – Governments need **real-time AI-driven insights** for decision-making.
#
# ![Wildfire Impact in Ecuador](abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/31758563907_9d16e7bb84_k%20(1).jpg)
#
# ---
#
# ## **🏡 2. The Community: Who Benefits?**
# ### **Primary Stakeholders in Ecuador**
# - **Local Fire & Disaster Agencies** – Need early warning systems & post-fire recovery analytics.
# - **Environmental & Conservation Groups** – Protecting Ecuador’s fragile ecosystems.
# - **Urban Planners & Governments** – Using fire data for land-use policies & infrastructure planning.
# - **Indigenous & Rural Communities** – Living near high-risk fire zones, requiring fire mitigation strategies.
#
# ### **🌍 Global Impact**
# This AI-driven approach can **scale globally**, supporting **fire-prone regions** like:
# ✔ Amazon Basin
# ✔ California, USA
# ✔ Australia
# ✔ Southern Europe
#
# ---
#
# ## **🖥 3. The Tech Stack: Microsoft + Esri ArcGIS Pro**
# To solve the **fire intelligence challenge**, we leveraged **AI-powered geospatial technology** with:
#
# ### **🔹 Microsoft Fabric**
# - **Data Engineering & Processing** – Managed large-scale Landsat & fire datasets.
# - **Power BI Integration** – Visualized wildfire risk trends.
# - **AI & Machine Learning Models** – Predicted burn severity & post-fire recovery patterns.
#
# ### **🔹 Esri ArcGIS Pro**
# - **Raster Analysis & Change Detection** – Using NBR & NDVI to quantify fire impact.
# - **Geospatial AI** – AI-driven pattern recognition for early warning signals.
# - **Interactive Fire Maps** – Community-driven mapping & risk assessment tools.
#
# ### **🛰 Landsat & AI Integration**
# 1️⃣ Landsat Data (2020–2024) → Downloaded via ESPA & Bulk Downloader.
# 2️⃣ Microsoft Fabric → AI-based data preprocessing & real-time analytics.
# 3️⃣ ArcGIS Pro → Spatial analysis, visualization, and decision support.
#
# ![Satellite View of Wildfire Regions](abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/32284026688_3ce17103cc_k%20(1).jpg)
#
# ---
#
# ## **🚀 4. The Solution: AI-Powered Fire Intelligence**
# ### **🔥 How Our AI Model Works**
# Our **fire analysis model** integrates **satellite imagery, AI, and geospatial tools** to:
# ✅ **Detect wildfires early** using NBR, NDVI, and SWIR analysis.
# ✅ **Analyze fire spread & severity** through multi-temporal Landsat imagery.
# ✅ **Predict recovery patterns** based on post-fire vegetation trends.
# ✅ **Generate risk maps** for **emergency responders & policymakers**.
#
# ### **📈 Data-Driven Insights**
# Our model provides:
# ✔ **Historical Fire Trends** – Understanding how wildfires have evolved over 4 years.
# ✔ **Real-Time Fire Risk Assessment** – Identifying high-risk zones before fires spread.
# ✔ **Recovery Monitoring** – Evaluating regrowth in burned landscapes.
#
# ![Ecuador Fire Analysis Visualization](abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/52843874080_fac154dcb7_k%20(1).jpg)
#
# ---
#
# ## **🌎 5. Ecuador’s Role: A Model for AI-Driven Disaster Resilience**
# Ecuador represents a **critical case study** for **AI in disaster resilience**:
# - **Diverse Terrain** → From rainforests to urban centers, requiring **custom fire risk models**.
# - **Growing Urbanization** → New developments increase **human-driven fire risks**.
# - **Policy Implications** → Ecuador’s government can **integrate AI into national wildfire policies**.
#
# Our approach offers a **scalable AI model** that can **be adapted to other fire-prone countries**.
#
# ![Community Impact of Wildfires](abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/54244255899_7dca1f59b3_k%20(1).jpg)
#
# ---
#
# ## **🎯 6. Key Takeaways: AI + GIS for Wildfire Risk**
# ### **🔑 What We Learned**
# ✔ AI-powered **geospatial analysis transforms fire monitoring**.
# ✔ **Microsoft Fabric + ArcGIS Pro** = **A scalable, cloud-based fire intelligence solution**.
# ✔ **Early warning systems save lives** – Real-time AI insights reduce disaster response times.
# ✔ **Community-driven mapping strengthens resilience** – Local collaboration improves fire mitigation strategies.
#
# ---
#
#
# ## **🔮 7. The Future: Scaling AI & GIS for Global Wildfire Response**
# This project is just the beginning! **Next steps include:**
# ✅ **Expanding to real-time wildfire monitoring** with MODIS & VIIRS data.
# ✅ **Developing predictive models** for **fire behavior & risk mapping**.
# ✅ **Integrating UAV & Drone Data** for **on-the-ground validation**.
# ✅ **Creating Open-Source Fire Dashboards** for **government & community use**.
#
# By combining **Esri GIS expertise** with **Microsoft’s AI-driven cloud infrastructure**, we can create a **new standard for global wildfire intelligence**.
#
# ---
#
# ## **📌 The Power of AI in Disaster Resilience**
# This **MSLA Ecuador Fire Project** demonstrates how **AI, remote sensing, and GIS** can:
# ✔ **Protect lives & ecosystems** from climate-driven disasters.
# ✔ **Empower governments** with actionable, real-time fire insights.
# ✔ **Drive innovation** in wildfire risk management worldwide.
#
# **MSLA Ecuador Fire Project** 🚀 | *Microsoft Fabric + ArcGIS Pro Integration*

# %% [markdown]
# ### Pre-Fire January 2024 - Landsat

# %%
geo_tiff_path = "abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/LC08_L2SP_008062_20240113_20240123_02_T1_SR_B5.TIF"
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 24, Finished, Available, Finished)

# %%
# !pip install adlfs rasterio fsspec
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 27, Finished, Available, Finished)
# ...
#   Using cached rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# ...
#   Using cached affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# ...
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# ...
# Using cached rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
# Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Using cached affine-2.4.0-py3-none-any.whl (15 kB)
# Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# ...

# %%
from adlfs import AzureBlobFileSystem
import rasterio
import fsspec
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 28, Finished, Available, Finished)

# %%
# Connect to Microsoft Fabric OneLake using AzureBlobFileSystem
abfs = AzureBlobFileSystem(
    account_name="onelake",
    anon=False  # Ensure authentication is required
)

# Define the correct file path
geo_tiff_path = "abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/LC08_L2SP_008062_20240113_20240123_02_T1_SR_B5.TIF"
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 29, Finished, Available, Finished)

# %%
# Open the TIF file directly from OneLake
with fsspec.open(geo_tiff_path, mode="rb", filesystem=abfs) as f:
    with rasterio.open(f) as src:
        raster = src.read(1)  # Read first band
        print("Raster Shape:", raster.shape)
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 30, Finished, Available, Finished)
# Raster Shape: (7741, 7591)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.imshow(raster, cmap='inferno')
plt.colorbar(label="Pixel Value")
plt.title("Pre-Fire Map Tile with Some Cloud Cover")
plt.show()
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 33, Finished, Available, Finished)

# %%
with fsspec.open(geo_tiff_path, mode="rb", filesystem=abfs) as f:
    with rasterio.open(f) as src:
        print("CRS:", src.crs)  # Coordinate Reference System
        print("Bounds:", src.bounds)  # Geospatial extent
        print("Transform:", src.transform)  # Pixel-to-world transformation
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 34, Finished, Available, Finished)
# CRS: EPSG:32618
# Bounds: BoundingBox(left=273285.0, bottom=-436215.0, right=501015.0, top=-203985.0)
# Transform: | 30.00, 0.00, 273285.00|
# | 0.00,-30.00,-203985.00|
# | 0.00, 0.00, 1.00|

# %%
# %pip install pyproj
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 40, Finished, Available, Finished)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 34.9 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
from pyproj import Transformer

# Define the CRS conversion: UTM Zone 18N (EPSG:32618) to WGS84 (EPSG:4326)
transformer = Transformer.from_crs("EPSG:32618", "EPSG:4326", always_xy=True)

# Extract UTM bounds from raster
left, bottom, right, top = 273285.0, -436215.0, 501015.0, -203985.0

# Convert to latitude/longitude
left_lon, bottom_lat = transformer.transform(left, bottom)
right_lon, top_lat = transformer.transform(right, top)

print(f"Geographic Bounds (WGS84):\n"
      f"Lower Left: ({left_lon}, {bottom_lat})\n"
      f"Upper Right: ({right_lon}, {top_lat})")
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 42, Finished, Available, Finished)
# Geographic Bounds (WGS84):
# Lower Left: (-77.04180362144399, -3.9439968325048214)
# Upper Right: (-74.99087374912455, -1.845509853107927)

# %% [markdown]
# ### Post-Fire Landsat October 2024 with QA Pixel for Cloud Masking

# %%
# Plot the Raw NBR Image
plt.figure(figsize=(10, 6))
plt.imshow(nbr, cmap="RdYlGn", vmin=-1, vmax=1)
plt.colorbar(label="NBR Value")
plt.title("Raw NBR Image (Before Cloud Masking)")
plt.axis("off")
plt.show()
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 51, Finished, Available, Finished)

# %% [markdown]
# ### Not correct calculation for NBR so need to recalculate

# %%
print("NBR Min:", np.min(nbr))
print("NBR Max:", np.max(nbr))
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 52, Finished, Available, Finished)
# NBR Min: -19999.0
# NBR Max: 10000.0

# %%
nbr = nbr / 10000.0  # Rescale NBR to -1 to 1 range
print("Rescaled NBR Min:", np.min(nbr))
print("Rescaled NBR Max:", np.max(nbr))
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 53, Finished, Available, Finished)
# Rescaled NBR Min: -1.9999
# Rescaled NBR Max: 1.0

# %%
plt.figure(figsize=(8, 6))
plt.imshow(nbr, cmap="RdYlGn", vmin=-1, vmax=1)
plt.colorbar(label="NBR Value")
plt.title("Corrected NBR Image (Scaled to -1 to 1)")
plt.show()
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 54, Finished, Available, Finished)

# %%
import fsspec
import rasterio
import numpy as np
import matplotlib.pyplot as plt

# Define file paths
nbr_path = "abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/LC08_L2SP_009060_20241002_20241008_02_T1_SR_NBR.tif"
qa_path = "abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/LC08_L2SP_009060_20241002_20241008_02_T1_QA_PIXEL.tif"

# Open the files
with fsspec.open(nbr_path, mode="rb", filesystem="abfs") as nbr_f, \
     fsspec.open(qa_path, mode="rb", filesystem="abfs") as qa_f:
    
    with rasterio.open(nbr_f) as nbr_src, rasterio.open(qa_f) as qa_src:
        nbr = nbr_src.read(1).astype(float)
        qa_pixel = qa_src.read(1)

        # Scale NBR to -1 to 1 range
        nbr = np.clip(nbr / 10000.0, -1, 1)

        # Extract cloud bits (Bit 4 = Cloud Confidence, Bit 5 = Cloud Shadow)
        cloud_mask = ((qa_pixel & (1 << 4)) > 0) | ((qa_pixel & (1 << 5)) > 0)

        # Apply the cloud mask
        nbr[cloud_mask] = np.nan  # Mask cloudy pixels

# Plot the Cloud-Masked NBR
plt.figure(figsize=(8, 6))
plt.imshow(nbr, cmap="RdYlGn", vmin=-1, vmax=1)
plt.colorbar(label="NBR Value")
plt.title("Cloud-Free NBR")
plt.axis("off")  # Hide axes
plt.show()
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 56, Finished, Available, Finished)

# %%
import fsspec
import rasterio

# Define the file path for the NBR raster
nbr_path = "abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/LC08_L2SP_009060_20241002_20241008_02_T1_SR_NBR.tif"

# Open the NBR raster file
with fsspec.open(nbr_path, mode="rb", filesystem="abfs") as nbr_f:
    with rasterio.open(nbr_f) as nbr_src:
        # Extract metadata
        crs = nbr_src.crs  # Coordinate Reference System
        bounds = nbr_src.bounds  # Bounding Box
        transform = nbr_src.transform  # Affine Transform

        print(f"CRS: {crs}")
        print(f"Bounds: {bounds}")  # Left, Bottom, Right, Top in projected coordinates
        print(f"Transform: {transform}")  # Pixel size and transformation details
# Out:
# StatementMeta(, 2e3329c9-58d3-4360-b595-b0b4ef2e0d0c, 57, Finished, Available, Finished)
# CRS: EPSG:32618
# Bounds: BoundingBox(left=172185.0, bottom=-116415.0, right=399915.0, top=115815.0)
# Transform: | 30.00, 0.00, 172185.00|
# | 0.00,-30.00, 115815.00|
# | 0.00, 0.00, 1.00|

# %%
# %pip install rasterio
# Out:
# StatementMeta(, c899be7c-791b-48be-9ec0-b37d7d9ac282, 8, Finished, Available, Finished)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 89.2 MB/s eta 0:00:00:00:0100:01
# ...
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import rasterio
import fsspec
import numpy as np
import matplotlib.pyplot as plt
# Out:
# StatementMeta(, c899be7c-791b-48be-9ec0-b37d7d9ac282, 10, Finished, Available, Finished)

# %%
# Define file paths for the NBR images
nbr_paths = {
    "NBR_1": "abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/LC08_L2SP_008062_20240113_20240123_02_T1_SR_NBR.tif",
    "NBR_2": "abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/LC08_L2SP_009060_20240120_20240129_02_T2_SR_NBR.tif"
}

# Define file paths for the QA_PIXEL images
qa_paths = {
    "QA_1": "abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/LC08_L2SP_008062_20240113_20240123_02_T1_QA_PIXEL.tif",
    "QA_2": "abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/LC08_L2SP_009060_20240120_20240129_02_T2_SR_NBR.tif"
}
# Out:
# StatementMeta(, c899be7c-791b-48be-9ec0-b37d7d9ac282, 11, Finished, Available, Finished)

# %%
def load_tif(file_path):
    """Load a raster TIFF file from Microsoft Fabric OneLake"""
    with fsspec.open(file_path, mode="rb", filesystem="abfs") as f:
        with rasterio.open(f) as src:
            data = src.read(1)  # Read first band
            meta = src.meta  # Get metadata
            print(f"Loaded: {file_path.split('/')[-1]}")
            print("Metadata:", meta)
            return data, meta

# Load all NBR and QA_PIXEL files
nbr_data = {key: load_tif(nbr_paths[key]) for key in nbr_paths}
qa_data = {key: load_tif(qa_paths[key]) for key in qa_paths}
# Out:
# StatementMeta(, c899be7c-791b-48be-9ec0-b37d7d9ac282, 12, Finished, Available, Finished)
# Loaded: LC08_L2SP_008062_20240113_20240123_02_T1_SR_NBR.tif
# Metadata: {'driver': 'GTiff', 'dtype': 'int16', 'nodata': -19999.0, 'width': 7591, 'height': 7741, 'count': 1, 'crs': CRS.from_wkt('PROJCS["WGS 84 / UTM zone 18N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-75],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32618"]]'), 'transform': Affine(30.0, 0.0, 273285.0,
#        0.0, -30.0, -203985.0)}
# ...

# %%
def apply_cloud_mask(nbr, qa):
    """Mask out clouds using the QA_PIXEL band"""
    # Extract the first element if it's a tuple
    if isinstance(nbr, tuple):
        nbr = nbr[0]
    if isinstance(qa, tuple):
        qa = qa[0]

    # Apply cloud mask using bitwise operation
    cloud_mask = (qa & 0b110000000000) == 0  # Mask clouds (bits 12 and 13)
    return np.where(cloud_mask, nbr, np.nan)  # Replace clouds with NaN
# Out:
# StatementMeta(, c899be7c-791b-48be-9ec0-b37d7d9ac282, 16, Finished, Available, Finished)

# %%
key_mapping = {'NBR_1': 'QA_1', 'NBR_2': 'QA_2'}

# Apply cloud masking while ensuring the correct data format
nbr_cleaned = {
    nbr_key: apply_cloud_mask(nbr_data[nbr_key], qa_data[qa_key]) 
    for nbr_key, qa_key in key_mapping.items()
}
# Out:
# StatementMeta(, c899be7c-791b-48be-9ec0-b37d7d9ac282, 17, Finished, Available, Finished)

# %%
# Check the keys in the dictionaries
print(f"NBR Data Keys: {nbr_data.keys()}")
print(f"QA Data Keys: {qa_data.keys()}")

# Check the shape and type of data for each key
for key in nbr_data:
    print(f"{key} - NBR Shape: {nbr_data[key][0].shape}, Type: {type(nbr_data[key][0])}")

for key in qa_data:
    print(f"{key} - QA Shape: {qa_data[key][0].shape}, Type: {type(qa_data[key][0])}")
# Out:
# StatementMeta(, c899be7c-791b-48be-9ec0-b37d7d9ac282, 18, Finished, Available, Finished)
# NBR Data Keys: dict_keys(['NBR_1', 'NBR_2'])
# QA Data Keys: dict_keys(['QA_1', 'QA_2'])
# NBR_1 - NBR Shape: (7741, 7591), Type: <class 'numpy.ndarray'>
# NBR_2 - NBR Shape: (7741, 7591), Type: <class 'numpy.ndarray'>
# QA_1 - QA Shape: (7741, 7591), Type: <class 'numpy.ndarray'>
# QA_2 - QA Shape: (7741, 7591), Type: <class 'numpy.ndarray'>

# %%
import matplotlib.pyplot as plt

# Select a sample key to visualize (assuming "NBR_1" and "QA_1" exist)
sample_nbr_key = "NBR_1"
sample_qa_key = "QA_1"

# Extract data (handle tuples)
nbr_array = nbr_data[sample_nbr_key][0] if isinstance(nbr_data[sample_nbr_key], tuple) else nbr_data[sample_nbr_key]
qa_array = qa_data[sample_qa_key][0] if isinstance(qa_data[sample_qa_key], tuple) else qa_data[sample_qa_key]

# Plot the NBR image
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.imshow(nbr_array, cmap="RdYlGn", vmin=-1, vmax=1)
plt.colorbar(label="NBR Value")
plt.title("Raw NBR Image")

# Plot the QA image
plt.subplot(1, 2, 2)
plt.imshow(qa_array, cmap="gray")
plt.colorbar(label="QA Value")
plt.title("QA Pixel Image")

plt.show()
# Out:
# StatementMeta(, c899be7c-791b-48be-9ec0-b37d7d9ac282, 19, Finished, Available, Finished)

# %%
import rasterio
import fsspec
import numpy as np
import matplotlib.pyplot as plt

# Define paths to the NBR and QA Pixel files
file_paths = {
    "NBR_1": "abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/LC08_L2SP_008062_20240113_20240123_02_T1_SR_NBR.tif",
    "QA_1": "abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/LC08_L2SP_008062_20240113_20240123_02_T1_QA_PIXEL.tif",
    "NBR_2": "abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/LC08_L2SP_009060_20240120_20240129_02_T2_SR_NBR.tif",
    "QA_2": "abfss://1f4c7e02-49f0-4c83-97b4-5389ffbe265a@onelake.dfs.fabric.microsoft.com/0a5686f0-3f34-48a2-b48d-a55a79cd231d/Files/LC08_L2SP_009060_20240120_20240129_02_T2_SR_NBR.tif"
}

# Dictionary to store loaded raster data
nbr_data = {}
qa_data = {}

# Load the raster files
for key, path in file_paths.items():
    with fsspec.open(path, mode="rb") as f:
        with rasterio.open(f) as src:
            if "NBR" in key:
                nbr_data[key] = src.read(1).astype(float)  # Convert to float for scaling
            elif "QA" in key:
                qa_data[key] = src.read(1)  # QA Pixel values are integers
# Out:
# StatementMeta(, c899be7c-791b-48be-9ec0-b37d7d9ac282, 24, Finished, Available, Finished)

# %%
# Scale the NBR data to range -1 to 1
for key in nbr_data:
    nbr_data[key] = nbr_data[key] / 10000.0
# Out:
# StatementMeta(, c899be7c-791b-48be-9ec0-b37d7d9ac282, 25, Finished, Available, Finished)

# %%
# Function to plot NBR and QA images side by side
def plot_nbr_qa(nbr_array, qa_array, title):
    plt.figure(figsize=(12, 5))

    # Plot NBR Image
    plt.subplot(1, 2, 1)
    plt.imshow(nbr_array, cmap="RdYlGn", vmin=-1, vmax=1)
    plt.colorbar(label="NBR Value")
    plt.title(f"{title} - NBR")

    # Plot QA Image
    plt.subplot(1, 2, 2)
    plt.imshow(qa_array, cmap="gray")
    plt.colorbar(label="QA Value")
    plt.title(f"{title} - QA Pixel")

    plt.show()

# Plot both images
plot_nbr_qa(nbr_data["NBR_1"], qa_data["QA_1"], "Dataset 1")
plot_nbr_qa(nbr_data["NBR_2"], qa_data["QA_2"], "Dataset 2")
# Out:
# StatementMeta(, c899be7c-791b-48be-9ec0-b37d7d9ac282, 26, Finished, Available, Finished)

# %%
def apply_cloud_mask(nbr, qa):
    """Mask out only high-confidence clouds (bits 12-13 == 2 or 3)"""
    cloud_mask = ((qa >> 12) & 3) >= 2  # Only mask 2 (medium confidence) and 3 (high confidence)
    return np.where(cloud_mask, np.nan, nbr)  # Replace cloud pixels with NaN

# Apply the updated masking function
nbr_cleaned["NBR_1_Clean"] = apply_cloud_mask(nbr_data["NBR_1"], qa_data["QA_1"])
nbr_cleaned["NBR_2_Clean"] = apply_cloud_mask(nbr_data["NBR_2"], qa_data["QA_2"])

# Visualize again
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))

# Plot cloud-masked Dataset 1
plt.subplot(2, 1, 1)
plt.imshow(nbr_cleaned["NBR_1_Clean"], cmap="RdYlGn", vmin=-1, vmax=1)
plt.colorbar(label="NBR Value")
plt.title("Cloud-Free NBR Dataset 1 (Fixed Masking)")

# Plot cloud-masked Dataset 2
plt.subplot(2, 1, 2)
plt.imshow(nbr_cleaned["NBR_2_Clean"], cmap="RdYlGn", vmin=-1, vmax=1)
plt.colorbar(label="NBR Value")
plt.title("Cloud-Free NBR Dataset 2 (Fixed Masking)")

plt.show()
# Out:
# StatementMeta(, c899be7c-791b-48be-9ec0-b37d7d9ac282, 32, Finished, Available, Finished)

# %% [markdown]
# ---
#
# ## **🌍 Conclusion: A New Era in Wildfire Intelligence**
# Wildfires are no longer seasonal threats—they are **accelerating due to climate change**, affecting ecosystems, communities, and economies worldwide.
# The **MSLA Ecuador Fire Project** demonstrates how **AI-driven geospatial intelligence** can transform wildfire monitoring, response, and prevention.
#
# ### **🔹 From Ecuador to the World**
# While this project focuses on **Ecuador**, our methodology can **scale globally** to other fire-prone regions.
# By integrating **satellite imagery, AI analytics, and cloud-based geospatial tools**, we provide a **scalable, adaptable** approach to wildfire intelligence.
#
# ### **🚀 The Future of AI + GIS in Disaster Resilience**
# The intersection of **Microsoft Fabric, Esri ArcGIS Pro, and remote sensing** paves the way for:
# ✅ **Real-time wildfire monitoring** with high-frequency satellite data.
# ✅ **AI-driven predictive modeling** to anticipate fire risk & improve prevention.
# ✅ **Community-centered mapping solutions** for localized fire mitigation strategies.
# ✅ **Government & emergency agency collaboration** for better disaster preparedness.
#
# ### **📢 Final Takeaways**
# ✔ **AI-powered geospatial intelligence is the future of wildfire risk management.**
# ✔ **Ecuador is a model for integrating AI into national disaster resilience strategies.**
# ✔ **By scaling this approach, we can drive innovation in global wildfire prevention.**
#
# As wildfires intensify worldwide, **leveraging AI, cloud computing, and GIS** is no longer an option—it is a necessity.
#
# 🔹 **MSLA Ecuador Fire Project** 🚀
# *Microsoft Fabric + ArcGIS Pro for AI-Driven Wildfire Resilience*
